# %%
# Answer_1

"""A class can be thought of as a category or a type of objects. For example, the class "Vehicle" can include objects such as "Car",
"Truck", and "Bicycle". Each object within the class "Vehicle" would have common attributes such as number of wheels and the ability to move,
but may also have unique attributes specific to their individual category (e.g. a car may have a specific number of doors,
while a truck may have a larger cargo capacity).

An object, on the other hand, is a specific instance of a class.
It is a unique entity that has its own set of attributes and behaviors defined by the class.
Continuing with the example of the class "Vehicle", an object could be a specific car with a certain make, model, and color.

So, in OOP, a class acts as a blueprint for objects and objects are specific realizations of the class,
each with its own set of attribute values and behaviors."""

# %%
# Answer_2

"""The four pillars of Object-Oriented Programming (OOP) are:

Encapsulation: This refers to the concept of wrapping data and behavior within an object, making it inaccessible to the outside world.
This helps to hide implementation details and promote modularity, making the code easier to maintain and update.

Abstraction: This refers to the process of hiding the implementation details and exposing only the necessary information to the outside world.
This helps to simplify the complexity of the system and make it easier to understand.

Inheritance: This refers to the ability of a new class to inherit the attributes and behaviors of an existing class. 
This helps to reuse and extend existing code, promoting code reuse and reducing code duplication.

Polymorphism: This refers to the ability of an object to take on many forms.
Polymorphism allows objects of different classes to be treated as objects of a common class, 
making the code more flexible and adaptable. This also enables method overloading and method overriding, 
where a single method can perform different operations based on the context in which it is called.

These four pillars form the foundation of Object-Oriented Programming and help to promote modularity, reusability, 
and maintainability in code."""

# %%
# Answer_3

"""The __init__() function is a special method in Python and is used to initialize objects of a class. 
It is called automatically when an object of the class is created and acts as a constructor for the class.

The __init__() function allows you to specify the attributes and values for an object when it is created.
You can also provide default values for attributes and assign values to attributes based on the arguments passed to the __init__() method.
This helps to ensure that each object has the correct initial state when it is created,
and eliminates the need for you to manually set the values for each object."""

class students:
    def __init__(self,name,Class,roll_number):
        self.name=name
        self.Class=Class
        self.roll_number=roll_number
    def details(self):
        return "the name is",self.name, "of class",self.Class,"roll_number is" ,self.roll_number
snehil=students("snehil",6,43)
snehil.details()
# Out:
# ('the name is', 'snehil', 'of class', 6, 'roll_number is', 43)

# %%
# Answer_4

"""In Object-Oriented Programming (OOP), self is a special reference to the current instance of the class. 
It is used to access the attributes and methods of the current object within the class.

In Python, when you define a method in a class, the first parameter is always self.
This parameter refers to the current instance of the class, and is used to access attributes and call methods on the object"""

# %%
# Answer_5

"""Inheritance is a key concept in Object-Oriented Programming (OOP) that allows you to create new classes that are based on existing classes. 
The new class is called a derived class or a subclass, and the existing class is called the base class or a superclass. 
The derived class inherits the attributes and behavior of the base class, and can also add new attributes and behavior of its own.

There are several types of inheritance in OOP, including:

Single Inheritance: Single inheritance occurs when a derived class inherits from a single base class. 
The derived class has access to all the attributes and methods of the base class, and can also add new attributes and methods of its own.
For example:"""
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def make_sound(self):
        print("Some generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof!")
"""Here, the Dog class inherits from the Animal class, and has access to all the attributes and methods of the Animal class.
The Dog class also overrides the make_sound method to provide its own implementation.

Multi-Level Inheritance: Multi-level inheritance occurs when a derived class inherits from a base class,
which in turn inherits from another base class. The derived class has access to all the attributes and methods of the base class and its ancestors.
For example:
"""
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def make_sound(self):
        print("Some generic animal sound")

class Mammal(Animal):
    def __init__(self, name, species, num_of_legs):
        Animal.__init__(self, name, species)
        self.num_of_legs = num_of_legs

class Dog(Mammal):
    def make_sound(self):
        print("Woof!")
"""Here, the Dog class inherits from the Mammal class, which in turn inherits from the Animal class. 
The Dog class has access to all the attributes and methods of the Animal and Mammal classes.

Multiple Inheritance: Multiple inheritance occurs when a derived class inherits from multiple base classes. 
The derived class has access to all the attributes and methods of the base classes. For example:
"""
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def make_sound(self):
        print("Some generic animal sound")

class RunningAnimal:
    def run(self):
        print("Running")

class Dog(Animal, RunningAnimal):
    def make_sound(self):
        print("Woof!")
"""Here, the Dog class inherits from both the Animal and RunningAnimal classes.
The Dog class has access to all the attributes and methods of both the Animal and RunningAnimal classes.

These are the most common types of inheritance in OOP. Inheritance allows you to create new classes that are based on existing classes, making"""
